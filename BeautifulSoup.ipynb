# %% [markdown]
# Starting of with the BeautifulSoup Program in Python for Machine Learning after completing the web scraping initials. This gonna contain videowise all the datas and the codes mainly for the BeautifulSoup tutorials. Thus let's start!! Here inthe below code we learnt how to simplify a complex and gibberish html code by using BeautifulSoup module and prettify() function.

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup("<html><p>sabhawdb<strong>Hello<a>Hello</html>")
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    sabhawdb
#    <strong>
#     Hello
#     <a>
#      Hello
#     </a>
#    </strong>
#   </p>
#  </body>
# </html>

# %% [markdown]
# Trying on the same feature on the old code of the weather app check whether it works as it is needed to. Code of the Python of the web scraping for weather report. In this we beautifully use Python modules and soup functions to cut down the proper and required contents directly by code. Here, we will not use

# %%
#Weather detector of required city
import re
import urllib.request
from bs4 import BeautifulSoup
#http://www.weather-forecast.com/locations/<Required City>/forecasts/latest
city = input("Enter your city: ")
url = "http://www.weather-forecast.com/locations/" + city + "/forecasts/latest"
data = urllib.request.urlopen(url).read()
data1 = data.decode("utf-8")
soup=BeautifulSoup(data1)
result=soup.find_all('span')
print(result[30].contents)
# Out:
# Enter your city: Lisbon
# ['Heavy rain (total 32mm), heaviest during Sat morning. Very mild (max 16°C on Sat afternoon, min 8°C on Thu morning). Wind will be generally light.']

# %% [markdown]
# The above weather detection ML model code is to be done in a more simpler way by drilling down into the content directly and specifically to the parts neede by **beautifulsoup** and **soup functions**. We have to *import BeautifulSoup from bs4* before doing the beautifulsoup code or using it's functions. Now in the below code we will learn to use requests module along with BeautifulSoup to call functions like *soup.find()*; where direct classes mentioned in html can be reffered to get the particular content.

# %%
import requests
from bs4 import BeautifulSoup
data=requests.get('https://www.dictionary.com/browse/Kill')
soup=BeautifulSoup(data.text,'html.parser')
data2=soup.find('div',{'class':'ESah86zaufmd2_YPdZtq'})
print(data2.string)
# Out:
# None

# %% [markdown]
# BeautifulSoup is done
